# %% [markdown]
# ## 讀取圖片
# 常見的套件:
# 1. skimage
# 2. PIL
# 3. OpenCV

# %% [markdown]
# # [教學目標]
# - 示範其他的讀圖檔方式

# %% [markdown]
# # [範例重點]
# - 用 skimage.io 讀取圖檔 (In[2], Out[2])
# - 用 PIL.Image 讀取圖檔 (In[3], Out[3])
# - 用 OpenCV 讀取圖檔 (In[4], Out[4])

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
import skimage.io as skio
img1 = skio.imread('data/example.jpg')
plt.imshow(img1)
plt.show()

# %%
from PIL import Image
img2 = Image.open('data/example.jpg') # 這時候還是 PIL object
img2 = np.array(img2)
plt.imshow(img2)
plt.show()

# %%
import cv2
img3 = cv2.imread('data/example.jpg')
plt.imshow(img3)
plt.show()

img3 = cv2.cvtColor(img3, cv2.COLOR_BGR2RGB)
plt.imshow(img3)
plt.show()

# %%
# !pip install opencv_python
# Out:
# Collecting opencv_python
#   Downloading https://files.pythonhosted.org/packages/0b/26/9af7fe21073cbef2f450a13ca18978732125fbb65cc56d173a7e82a9e111/opencv_python-4.2.0.32-cp36-cp36m-win_amd64.whl (33.0MB)
# Requirement already satisfied: numpy>=1.11.3 in c:\users\b9105\anaconda3\envs\tensorflow\lib\site-packages (from opencv_python) (1.17.4)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.2.0.32

# %% [markdown]
# ### 比較三種開圖方式的時間 - 比較讀取 1000 次

# %%
N_times = 1000

# %%
# %%timeit
im = np.array([skio.imread('data/example.jpg') for _ in range(N_times)])
# Out:
# 14.7 s ± 749 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
im = np.array([np.array(Image.open('data/example.jpg')) for _ in range(N_times)])
# Out:
# 14.1 s ± 387 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
im = np.array([cv2.cvtColor(cv2.imread('data/example.jpg'), cv2.COLOR_BGR2RGB) for _ in range(N_times)])
# Out:
# 22.5 s ± 2.37 s per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# ## 將影像存成 mat

# %%
import scipy.io as sio
sio.savemat(file_name='data/example.mat', mdict={'img': img1})

# %%
mat_arr = sio.loadmat('data/example.mat')
print(mat_arr.keys())
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'img'])

# %%
mat_arr = mat_arr['img']
print(mat_arr.shape)
# Out:
# (813, 771, 3)

# %%
plt.imshow(mat_arr)
plt.show()

# %% [markdown]
# # 練習時間
#
# ## 1-1 讀取 txt 檔
# * 請讀取 [text file](https://raw.githubusercontent.com/vashineyu/slides_and_others/master/tutorial/examples/imagenet_urls_examples.txt)
# * 懶人複製連結: https://raw.githubusercontent.com/vashineyu/slides_and_others/master/tutorial/examples/imagenet_urls_examples.txt
#
# ## 1-2 將所提供的 txt 轉成 pandas dataframe
#
# ## 2. 從所提供的 txt 中的連結讀取圖片，請讀取上面 data frame 中的前 5 張圖片
