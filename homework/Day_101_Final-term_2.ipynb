# %%
from keras import backend as K
from keras.models import Model
from tensorflow.keras.layers import Flatten, Dense, Dropout
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.xception import Xception
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.models import load_model  # 使用高階模型，keras 無法載入
import numpy as np
import pandas as pd
import os

# %%
# 資料路徑
DATASET_PATH  = '/content/drive/My Drive/MyPy/data'
# 影像大小
IMAGE_SIZE = (299, 299) # Xception 預訓練影像大小，resnet 為 (224, 224)
# 影像類別數
NUM_CLASSES = 5
# 若 GPU 記憶體不足，可調降 batch size 或凍結更多層網路
BATCH_SIZE = 16
# Epoch 數
NUM_EPOCHS = 200
# 模型輸出儲存的檔案
WEIGHTS_BEST = 'model-Xception-best.h5' # 最佳模型
WEIGHTS_LAST = 'model-Xception-last.h5' # 最終模型
# 是否載入已訓練模型
load_mode = True
# 是否使用目前最佳模型
use_best = True

# %%
# data augmentation
train_datagen = ImageDataGenerator(rescale=1./255,
                                   rotation_range=30,
                                   width_shift_range=0.2,
                                   height_shift_range=0.2,
                                   shear_range=0.2,
                                   zoom_range=0.2,
                                   channel_shift_range=10,
                                   horizontal_flip=True,
                                   fill_mode='nearest',
                                   validation_split=0.1)  # set validation split
# 切分訓練和驗證集
train_batches = train_datagen.flow_from_directory(DATASET_PATH + '/train',
                                                  target_size=IMAGE_SIZE,
                                                  interpolation='bicubic',
                                                  class_mode='categorical',
                                                  batch_size=BATCH_SIZE,
                                                  shuffle=True, 
                                                  subset='training') # set as training data

valid_batches = train_datagen.flow_from_directory(DATASET_PATH + '/train',
                                                  target_size=IMAGE_SIZE,
                                                  interpolation='bicubic',
                                                  class_mode='categorical',
                                                  batch_size=BATCH_SIZE,
                                                  shuffle=True,
                                                  subset='validation') # set as validation data

test_datagen = ImageDataGenerator(rescale=1./255)
test_batches = test_datagen.flow_from_directory(DATASET_PATH + '/test',
                                                  target_size=IMAGE_SIZE,
                                                  interpolation='bicubic',
                                                  class_mode=None,
                                                  shuffle=False,
                                                  batch_size=1,)

# 輸出各類別的索引值
print('----- train_batch ----- {} samples'.format(train_batches.samples))
for cls, idx in train_batches.class_indices.items():
    print('Class #{} = {}'.format(idx, cls))

# 輸出各類別的索引值
print('----- valid_batch ----- {} samples'.format(valid_batches.samples))
for cls, idx in valid_batches.class_indices.items():
    print('Class #{} = {}'.format(idx, cls))

# 輸出各類別的索引值
print('----- test_batch ----- {} samples'.format(test_batches.samples))
for cls, idx in test_batches.class_indices.items():
    print('Class #{} = {}'.format(idx, cls))
# Out:
# Found 2543 images belonging to 5 classes.
# Found 280 images belonging to 5 classes.
# Found 2000 images belonging to 1 classes.
# ----- train_batch ----- 2543 samples
# Class #0 = daisy
# Class #1 = dandelion
# Class #2 = rose
# Class #3 = sunflower
# Class #4 = tulip
# ----- valid_batch ----- 280 samples
# Class #0 = daisy
# Class #1 = dandelion
# Class #2 = rose
# Class #3 = sunflower
# Class #4 = tulip
# ----- test_batch ----- 2000 samples
# Class #0 = all

# %%
def lr_schedule(epoch):
    """Learning Rate Schedule
    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.
    # Arguments
        epoch (int): The number of epochs
    # Returns
        lr (float32): learning rate
    """
    global load_mode
    
    if load_mode:
        lr = 1e-4
    else:
        lr = 1e-3
    if epoch > 150:
        lr *= 0.5e-3
    elif epoch > 120:
        lr *= 1e-3
    elif epoch > 90:
        lr *= 1e-2
    elif epoch > 50:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr

# %%
# 准备模型保存路径。
save_dir = os.path.join(DATASET_PATH, 'saved_models')
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, WEIGHTS_BEST)

# 准备保存模型和学习速率调整的回调。
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_accuracy',
                             verbose=1,
                             save_best_only=True)

lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

callbacks = [checkpoint, lr_reducer, lr_scheduler]

# %%
# 以訓練好的 model 為基礎來建立模型，
if load_mode :
  # identical to the best one
  net_final = load_model(os.path.join(save_dir, WEIGHTS_BEST))
else:
  # 捨棄 Xception / ResNet50 頂層的 fully connected layers
#  net = ResNet50(include_top=True, weights='imagenet', input_tensor=None,
#                input_shape=(IMAGE_SIZE[0],IMAGE_SIZE[1],3))  
  net = Xception(include_top=True, weights='imagenet', input_tensor=None,
                input_shape=(IMAGE_SIZE[0],IMAGE_SIZE[1],3))
   
  # remove classification layer
  net.layers.pop()  # not work ?
  net = Model(inputs=net.input, outputs=net.layers[-2].output)

  # # 設定凍結與要進行訓練的網路層
  # for layer in net.layers:
  #     layer.trainable = False

  x = net.output
  #x = Flatten()(x)

  # 增加 DropOut layer
  x = Dropout(0.5)(x)

  # 增加 Dense layer，以 softmax 產生個類別的機率值
  output_layer = Dense(NUM_CLASSES, activation='softmax', name='softmax')(x)
  
  net_final = Model(inputs=net.input, outputs=output_layer)

# 使用 Adam optimizer，以較低的 learning rate 進行 fine-tuning
net_final.compile(loss='categorical_crossentropy',
              optimizer=Adam(lr=lr_schedule(0)),
              metrics=['accuracy'])

# 輸出整個網路結構
print(net_final.summary())
# Out:
# Learning rate:  0.0001
# Model: "model_8"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_10 (InputLayer)           [(None, 299, 299, 3) 0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 149, 149, 32) 864         input_10[0][0]
# __________________________________________________________________________________________________
# block1_conv1_bn (BatchNormaliza (None, 149, 149, 32) 128         block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_act (Activation)   (None, 149, 149, 32) 0           block1_conv1_bn[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 147, 147, 64) 18432       block1_conv1_act[0][0]
# __________________________________________________________________________________________________
# block1_conv2_bn (BatchNormaliza (None, 147, 147, 64) 256         block1_conv2[0][0]
# __________________________________________________________________________________________________
# block1_conv2_act (Activation)   (None, 147, 147, 64) 0           block1_conv2_bn[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1 (SeparableConv2 (None, 147, 147, 128 8768        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1_bn (BatchNormal (None, 147, 147, 128 512         block2_sepconv1[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_act (Activation (None, 147, 147, 128 0           block2_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2 (SeparableConv2 (None, 147, 147, 128 17536       block2_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_bn (BatchNormal (None, 147, 147, 128 512         block2_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 74, 74, 128)  8192        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 74, 74, 128)  0           block2_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 74, 74, 128)  512         conv2d_36[0][0]
# __________________________________________________________________________________________________
# add_108 (Add)                   (None, 74, 74, 128)  0           block2_pool[0][0]
#                                                                  batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1_act (Activation (None, 74, 74, 128)  0           add_108[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1 (SeparableConv2 (None, 74, 74, 256)  33920       block3_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1_bn (BatchNormal (None, 74, 74, 256)  1024        block3_sepconv1[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2_act (Activation (None, 74, 74, 256)  0           block3_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2 (SeparableConv2 (None, 74, 74, 256)  67840       block3_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2_bn (BatchNormal (None, 74, 74, 256)  1024        block3_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 37, 37, 256)  32768       add_108[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 37, 37, 256)  0           block3_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 37, 37, 256)  1024        conv2d_37[0][0]
# __________________________________________________________________________________________________
# add_109 (Add)                   (None, 37, 37, 256)  0           block3_pool[0][0]
#                                                                  batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1_act (Activation (None, 37, 37, 256)  0           add_109[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1 (SeparableConv2 (None, 37, 37, 728)  188672      block4_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1_bn (BatchNormal (None, 37, 37, 728)  2912        block4_sepconv1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2_act (Activation (None, 37, 37, 728)  0           block4_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2 (SeparableConv2 (None, 37, 37, 728)  536536      block4_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2_bn (BatchNormal (None, 37, 37, 728)  2912        block4_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 19, 19, 728)  186368      add_109[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, 19, 19, 728)  0           block4_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 19, 19, 728)  2912        conv2d_38[0][0]
# __________________________________________________________________________________________________
# add_110 (Add)                   (None, 19, 19, 728)  0           block4_pool[0][0]
#                                                                  batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1_act (Activation (None, 19, 19, 728)  0           add_110[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1 (SeparableConv2 (None, 19, 19, 728)  536536      block5_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1_bn (BatchNormal (None, 19, 19, 728)  2912        block5_sepconv1[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2_act (Activation (None, 19, 19, 728)  0           block5_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2 (SeparableConv2 (None, 19, 19, 728)  536536      block5_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2_bn (BatchNormal (None, 19, 19, 728)  2912        block5_sepconv2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3_act (Activation (None, 19, 19, 728)  0           block5_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3 (SeparableConv2 (None, 19, 19, 728)  536536      block5_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3_bn (BatchNormal (None, 19, 19, 728)  2912        block5_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_111 (Add)                   (None, 19, 19, 728)  0           block5_sepconv3_bn[0][0]
#                                                                  add_110[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1_act (Activation (None, 19, 19, 728)  0           add_111[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1 (SeparableConv2 (None, 19, 19, 728)  536536      block6_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1_bn (BatchNormal (None, 19, 19, 728)  2912        block6_sepconv1[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2_act (Activation (None, 19, 19, 728)  0           block6_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2 (SeparableConv2 (None, 19, 19, 728)  536536      block6_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2_bn (BatchNormal (None, 19, 19, 728)  2912        block6_sepconv2[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3_act (Activation (None, 19, 19, 728)  0           block6_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3 (SeparableConv2 (None, 19, 19, 728)  536536      block6_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3_bn (BatchNormal (None, 19, 19, 728)  2912        block6_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_112 (Add)                   (None, 19, 19, 728)  0           block6_sepconv3_bn[0][0]
#                                                                  add_111[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1_act (Activation (None, 19, 19, 728)  0           add_112[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1 (SeparableConv2 (None, 19, 19, 728)  536536      block7_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1_bn (BatchNormal (None, 19, 19, 728)  2912        block7_sepconv1[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2_act (Activation (None, 19, 19, 728)  0           block7_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2 (SeparableConv2 (None, 19, 19, 728)  536536      block7_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2_bn (BatchNormal (None, 19, 19, 728)  2912        block7_sepconv2[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3_act (Activation (None, 19, 19, 728)  0           block7_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3 (SeparableConv2 (None, 19, 19, 728)  536536      block7_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3_bn (BatchNormal (None, 19, 19, 728)  2912        block7_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_113 (Add)                   (None, 19, 19, 728)  0           block7_sepconv3_bn[0][0]
#                                                                  add_112[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1_act (Activation (None, 19, 19, 728)  0           add_113[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1 (SeparableConv2 (None, 19, 19, 728)  536536      block8_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1_bn (BatchNormal (None, 19, 19, 728)  2912        block8_sepconv1[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2_act (Activation (None, 19, 19, 728)  0           block8_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2 (SeparableConv2 (None, 19, 19, 728)  536536      block8_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2_bn (BatchNormal (None, 19, 19, 728)  2912        block8_sepconv2[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3_act (Activation (None, 19, 19, 728)  0           block8_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3 (SeparableConv2 (None, 19, 19, 728)  536536      block8_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3_bn (BatchNormal (None, 19, 19, 728)  2912        block8_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_114 (Add)                   (None, 19, 19, 728)  0           block8_sepconv3_bn[0][0]
#                                                                  add_113[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1_act (Activation (None, 19, 19, 728)  0           add_114[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1 (SeparableConv2 (None, 19, 19, 728)  536536      block9_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1_bn (BatchNormal (None, 19, 19, 728)  2912        block9_sepconv1[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2_act (Activation (None, 19, 19, 728)  0           block9_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2 (SeparableConv2 (None, 19, 19, 728)  536536      block9_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2_bn (BatchNormal (None, 19, 19, 728)  2912        block9_sepconv2[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3_act (Activation (None, 19, 19, 728)  0           block9_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3 (SeparableConv2 (None, 19, 19, 728)  536536      block9_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3_bn (BatchNormal (None, 19, 19, 728)  2912        block9_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_115 (Add)                   (None, 19, 19, 728)  0           block9_sepconv3_bn[0][0]
#                                                                  add_114[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1_act (Activatio (None, 19, 19, 728)  0           add_115[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1 (SeparableConv (None, 19, 19, 728)  536536      block10_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1_bn (BatchNorma (None, 19, 19, 728)  2912        block10_sepconv1[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2_act (Activatio (None, 19, 19, 728)  0           block10_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2 (SeparableConv (None, 19, 19, 728)  536536      block10_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2_bn (BatchNorma (None, 19, 19, 728)  2912        block10_sepconv2[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3_act (Activatio (None, 19, 19, 728)  0           block10_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3 (SeparableConv (None, 19, 19, 728)  536536      block10_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3_bn (BatchNorma (None, 19, 19, 728)  2912        block10_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_116 (Add)                   (None, 19, 19, 728)  0           block10_sepconv3_bn[0][0]
#                                                                  add_115[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1_act (Activatio (None, 19, 19, 728)  0           add_116[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1 (SeparableConv (None, 19, 19, 728)  536536      block11_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1_bn (BatchNorma (None, 19, 19, 728)  2912        block11_sepconv1[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2_act (Activatio (None, 19, 19, 728)  0           block11_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2 (SeparableConv (None, 19, 19, 728)  536536      block11_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2_bn (BatchNorma (None, 19, 19, 728)  2912        block11_sepconv2[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3_act (Activatio (None, 19, 19, 728)  0           block11_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3 (SeparableConv (None, 19, 19, 728)  536536      block11_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3_bn (BatchNorma (None, 19, 19, 728)  2912        block11_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_117 (Add)                   (None, 19, 19, 728)  0           block11_sepconv3_bn[0][0]
#                                                                  add_116[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1_act (Activatio (None, 19, 19, 728)  0           add_117[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1 (SeparableConv (None, 19, 19, 728)  536536      block12_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1_bn (BatchNorma (None, 19, 19, 728)  2912        block12_sepconv1[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2_act (Activatio (None, 19, 19, 728)  0           block12_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2 (SeparableConv (None, 19, 19, 728)  536536      block12_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2_bn (BatchNorma (None, 19, 19, 728)  2912        block12_sepconv2[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3_act (Activatio (None, 19, 19, 728)  0           block12_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3 (SeparableConv (None, 19, 19, 728)  536536      block12_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3_bn (BatchNorma (None, 19, 19, 728)  2912        block12_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_118 (Add)                   (None, 19, 19, 728)  0           block12_sepconv3_bn[0][0]
#                                                                  add_117[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_act (Activatio (None, 19, 19, 728)  0           add_118[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1 (SeparableConv (None, 19, 19, 728)  536536      block13_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_bn (BatchNorma (None, 19, 19, 728)  2912        block13_sepconv1[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_act (Activatio (None, 19, 19, 728)  0           block13_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2 (SeparableConv (None, 19, 19, 1024) 752024      block13_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_bn (BatchNorma (None, 19, 19, 1024) 4096        block13_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 10, 10, 1024) 745472      add_118[0][0]
# __________________________________________________________________________________________________
# block13_pool (MaxPooling2D)     (None, 10, 10, 1024) 0           block13_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 10, 10, 1024) 4096        conv2d_39[0][0]
# __________________________________________________________________________________________________
# add_119 (Add)                   (None, 10, 10, 1024) 0           block13_pool[0][0]
#                                                                  batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1 (SeparableConv (None, 10, 10, 1536) 1582080     add_119[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_bn (BatchNorma (None, 10, 10, 1536) 6144        block14_sepconv1[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_act (Activatio (None, 10, 10, 1536) 0           block14_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2 (SeparableConv (None, 10, 10, 2048) 3159552     block14_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_bn (BatchNorma (None, 10, 10, 2048) 8192        block14_sepconv2[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_act (Activatio (None, 10, 10, 2048) 0           block14_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 2048)         0           block14_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 2048)         0           avg_pool[0][0]
# __________________________________________________________________________________________________
# softmax (Dense)                 (None, 5)            10245       dropout_2[0][0]
# ==================================================================================================
# Total params: 20,871,725
# Trainable params: 20,817,197
# Non-trainable params: 54,528
# __________________________________________________________________________________________________
# None

# %%
# 訓練模型
net_final.fit_generator(train_batches,
                        steps_per_epoch = train_batches.samples // BATCH_SIZE,
                        validation_data = valid_batches,
                        validation_steps = valid_batches.samples // BATCH_SIZE,
                        epochs = NUM_EPOCHS,
                        verbose=1,
                        callbacks=callbacks)

# 儲存訓練好的模型
modelpath = os.path.join(save_dir, WEIGHTS_LAST)
net_final.save(modelpath)
# Out:
# Learning rate:  0.0001
# Epoch 1/200
# 158/158 [==============================] - ETA: 0s - loss: 0.0061 - accuracy: 0.9988
# Epoch 00001: val_accuracy improved from -inf to 0.94118, saving model to /content/drive/My Drive/MyPy/data/saved_models/model-Xception-best.h5
# 158/158 [==============================] - 1499s 9s/step - loss: 0.0061 - accuracy: 0.9988 - val_loss: 0.2497 - val_accuracy: 0.9412 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 2/200
# 158/158 [==============================] - ETA: 0s - loss: 0.0037 - accuracy: 0.9984
# Epoch 00002: val_accuracy improved from 0.94118 to 0.94853, saving model to /content/drive/My Drive/MyPy/data/saved_models/model-Xception-best.h5
# 158/158 [==============================] - 105s 663ms/step - loss: 0.0037 - accuracy: 0.9984 - val_loss: 0.1356 - val_accuracy: 0.9485 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 3/200
# 158/158 [==============================] - ETA: 0s - loss: 0.0037 - accuracy: 0.9992
# Epoch 00003: val_accuracy did not improve from 0.94853
# 158/158 [==============================] - 101s 640ms/step - loss: 0.0037 - accuracy: 0.9992 - val_loss: 0.2384 - val_accuracy: 0.9449 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 4/200
# 158/158 [==============================] - ETA: 0s - loss: 0.0060 - accuracy: 0.9984
# Epoch 00004: val_accuracy did not improve from 0.94853
# 158/158 [==============================] - 101s 638ms/step - loss: 0.0060 - accuracy: 0.9984 - val_loss: 0.3052 - val_accuracy: 0.9338 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 5/200
# 158/158 [==============================] - ETA: 0s - loss: 0.0060 - accuracy: 0.9992
# Epoch 00005: val_accuracy improved from 0.94853 to 0.95221, saving model to /content/drive/My Drive/MyPy/data/saved_models/model-Xception-best.h5
# 158/158 [==============================] - 104s 656ms/step - loss: 0.0060 - accuracy: 0.9992 - val_loss: 0.1590 - val_accuracy: 0.9522 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 6/200
# 158/158 [==============================] - ETA: 0s - loss: 0.0042 - accuracy: 0.9988
# Epoch 00006: val_accuracy did not improve from 0.95221
# 158/158 [==============================] - 101s 639ms/step - loss: 0.0042 - accuracy: 0.9988 - val_loss: 0.2304 - val_accuracy: 0.9301 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 7/200
# 158/158 [==============================] - ETA: 0s - loss: 0.0066 - accuracy: 0.9972
# Epoch 00007: val_accuracy did not improve from 0.95221
# 158/158 [==============================] - 101s 637ms/step - loss: 0.0066 - accuracy: 0.9972 - val_loss: 0.2542 - val_accuracy: 0.9522 - lr: 3.1623e-05
# Learning rate:  0.0001
# Epoch 8/200
# 158/158 [==============================] - ETA: 0s - loss: 0.0088 - accuracy: 0.9976
# Epoch 00008: val_accuracy did not improve from 0.95221
# 158/158 [==============================] - 101s 638ms/step - loss: 0.0088 - accuracy: 0.9976 - val_loss: 0.1169 - val_accuracy: 0.9485 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 9/200
# 158/158 [==============================] - ETA: 0s - loss: 0.0081 - accuracy: 0.9984
# Epoch 00009: val_accuracy did not improve from 0.95221
# 158/158 [==============================] - 101s 638ms/step - loss: 0.0081 - accuracy: 0.9984 - val_loss: 0.1755 - val_accuracy: 0.9522 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 10/200
# 158/158 [==============================] - ETA: 0s - loss: 0.0023 - accuracy: 0.9992
# Epoch 00010: val_accuracy did not improve from 0.95221
# 158/158 [==============================] - 101s 636ms/step - loss: 0.0023 - accuracy: 0.9992 - val_loss: 0.1563 - val_accuracy: 0.9522 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 11/200
# 158/158 [==============================] - ETA: 0s - loss: 0.0045 - accuracy: 0.9988
# Epoch 00011: val_accuracy did not improve from 0.95221
# 158/158 [==============================] - 101s 638ms/step - loss: 0.0045 - accuracy: 0.9988 - val_loss: 0.2296 - val_accuracy: 0.9449 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 12/200
# 158/158 [==============================] - ETA: 0s - loss: 0.0038 - accuracy: 0.9992
# Epoch 00012: val_accuracy did not improve from 0.95221
# 158/158 [==============================] - 101s 640ms/step - loss: 0.0038 - accuracy: 0.9992 - val_loss: 0.2017 - val_accuracy: 0.9522 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 13/200
# 158/158 [==============================] - ETA: 0s - loss: 0.0039 - accuracy: 0.9984
# Epoch 00013: val_accuracy did not improve from 0.95221
# 158/158 [==============================] - 101s 640ms/step - loss: 0.0039 - accuracy: 0.9984 - val_loss: 0.2560 - val_accuracy: 0.9154 - lr: 3.1623e-05
# Learning rate:  0.0001
# Epoch 14/200
# 158/158 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 0.9996
# Epoch 00014: val_accuracy did not improve from 0.95221
# 158/158 [==============================] - 101s 640ms/step - loss: 0.0017 - accuracy: 0.9996 - val_loss: 0.2335 - val_accuracy: 0.9522 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 15/200
# 158/158 [==============================] - ETA: 0s - loss: 0.0031 - accuracy: 0.9984
# Epoch 00015: val_accuracy did not improve from 0.95221
# 158/158 [==============================] - 101s 642ms/step - loss: 0.0031 - accuracy: 0.9984 - val_loss: 0.2178 - val_accuracy: 0.9412 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 16/200
# 158/158 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 0.9996
# Epoch 00016: val_accuracy improved from 0.95221 to 0.95588, saving model to /content/drive/My Drive/MyPy/data/saved_models/model-Xception-best.h5
# 158/158 [==============================] - 105s 664ms/step - loss: 0.0015 - accuracy: 0.9996 - val_loss: 0.1615 - val_accuracy: 0.9559 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 17/200
# 158/158 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 0.9996
# Epoch 00017: val_accuracy did not improve from 0.95588
# 158/158 [==============================] - 104s 655ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.2919 - val_accuracy: 0.9412 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 18/200
# 158/158 [==============================] - ETA: 0s - loss: 0.0031 - accuracy: 0.9988
# Epoch 00018: val_accuracy did not improve from 0.95588
# 158/158 [==============================] - 103s 654ms/step - loss: 0.0031 - accuracy: 0.9988 - val_loss: 0.2210 - val_accuracy: 0.9485 - lr: 3.1623e-05
# Learning rate:  0.0001
# Epoch 19/200
# 158/158 [==============================] - ETA: 0s - loss: 0.0029 - accuracy: 0.9988
# Epoch 00019: val_accuracy did not improve from 0.95588
# 158/158 [==============================] - 103s 654ms/step - loss: 0.0029 - accuracy: 0.9988 - val_loss: 0.2586 - val_accuracy: 0.9412 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 20/200
# 158/158 [==============================] - ETA: 0s - loss: 0.0020 - accuracy: 0.9996
# Epoch 00020: val_accuracy did not improve from 0.95588
# 158/158 [==============================] - 103s 654ms/step - loss: 0.0020 - accuracy: 0.9996 - val_loss: 0.2180 - val_accuracy: 0.9559 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 21/200
# 158/158 [==============================] - ETA: 0s - loss: 0.0035 - accuracy: 0.9992
# Epoch 00021: val_accuracy did not improve from 0.95588
# 158/158 [==============================] - 104s 655ms/step - loss: 0.0035 - accuracy: 0.9992 - val_loss: 0.2346 - val_accuracy: 0.9375 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 22/200
# 158/158 [==============================] - ETA: 0s - loss: 0.0073 - accuracy: 0.9992
# Epoch 00022: val_accuracy improved from 0.95588 to 0.96324, saving model to /content/drive/My Drive/MyPy/data/saved_models/model-Xception-best.h5
# 158/158 [==============================] - 107s 680ms/step - loss: 0.0073 - accuracy: 0.9992 - val_loss: 0.1708 - val_accuracy: 0.9632 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 23/200
# 158/158 [==============================] - ETA: 0s - loss: 0.0010 - accuracy: 1.0000
# Epoch 00023: val_accuracy did not improve from 0.96324
# 158/158 [==============================] - 104s 661ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.2171 - val_accuracy: 0.9412 - lr: 3.1623e-05
# Learning rate:  0.0001
# Epoch 24/200
# 158/158 [==============================] - ETA: 0s - loss: 9.3926e-04 - accuracy: 1.0000
# Epoch 00024: val_accuracy did not improve from 0.96324
# 158/158 [==============================] - 102s 643ms/step - loss: 9.3926e-04 - accuracy: 1.0000 - val_loss: 0.1933 - val_accuracy: 0.9596 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 25/200
# 158/158 [==============================] - ETA: 0s - loss: 0.0026 - accuracy: 0.9984
# Epoch 00025: val_accuracy did not improve from 0.96324
# 158/158 [==============================] - 101s 639ms/step - loss: 0.0026 - accuracy: 0.9984 - val_loss: 0.2516 - val_accuracy: 0.9338 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 26/200
# 158/158 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 0.9996
# Epoch 00026: val_accuracy did not improve from 0.96324
# 158/158 [==============================] - 103s 649ms/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.2690 - val_accuracy: 0.9301 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 27/200
# 158/158 [==============================] - ETA: 0s - loss: 0.0047 - accuracy: 0.9988
# Epoch 00027: val_accuracy did not improve from 0.96324
# 158/158 [==============================] - 103s 652ms/step - loss: 0.0047 - accuracy: 0.9988 - val_loss: 0.2289 - val_accuracy: 0.9522 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 28/200
# 158/158 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.9992
# Epoch 00028: val_accuracy did not improve from 0.96324
# 158/158 [==============================] - 103s 653ms/step - loss: 0.0019 - accuracy: 0.9992 - val_loss: 0.2035 - val_accuracy: 0.9632 - lr: 3.1623e-05
# Learning rate:  0.0001
# Epoch 29/200
# 158/158 [==============================] - ETA: 0s - loss: 0.0080 - accuracy: 0.9972
# Epoch 00029: val_accuracy did not improve from 0.96324
# 158/158 [==============================] - 104s 658ms/step - loss: 0.0080 - accuracy: 0.9972 - val_loss: 0.2345 - val_accuracy: 0.9449 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 30/200
# 158/158 [==============================] - ETA: 0s - loss: 0.0025 - accuracy: 0.9992
# Epoch 00030: val_accuracy did not improve from 0.96324
# 158/158 [==============================] - 104s 658ms/step - loss: 0.0025 - accuracy: 0.9992 - val_loss: 0.2100 - val_accuracy: 0.9485 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 31/200
# 158/158 [==============================] - ETA: 0s - loss: 0.0067 - accuracy: 0.9988
# Epoch 00031: val_accuracy did not improve from 0.96324
# 158/158 [==============================] - 104s 660ms/step - loss: 0.0067 - accuracy: 0.9988 - val_loss: 0.2380 - val_accuracy: 0.9375 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 32/200
# 158/158 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 0.9996
# Epoch 00032: val_accuracy did not improve from 0.96324
# 158/158 [==============================] - 105s 662ms/step - loss: 0.0017 - accuracy: 0.9996 - val_loss: 0.2488 - val_accuracy: 0.9412 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 33/200
# 158/158 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 0.9996
# Epoch 00033: val_accuracy improved from 0.96324 to 0.96691, saving model to /content/drive/My Drive/MyPy/data/saved_models/model-Xception-best.h5
# 158/158 [==============================] - 108s 684ms/step - loss: 0.0021 - accuracy: 0.9996 - val_loss: 0.1481 - val_accuracy: 0.9669 - lr: 3.1623e-05
# Learning rate:  0.0001
# Epoch 34/200
# 158/158 [==============================] - ETA: 0s - loss: 0.0027 - accuracy: 0.9992
# Epoch 00034: val_accuracy did not improve from 0.96691
# 158/158 [==============================] - 105s 664ms/step - loss: 0.0027 - accuracy: 0.9992 - val_loss: 0.1501 - val_accuracy: 0.9522 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 35/200
# 158/158 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 1.0000
# Epoch 00035: val_accuracy did not improve from 0.96691
# 158/158 [==============================] - 105s 662ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1307 - val_accuracy: 0.9522 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 36/200
# 158/158 [==============================] - ETA: 0s - loss: 0.0088 - accuracy: 0.9976
# Epoch 00036: val_accuracy did not improve from 0.96691
# 158/158 [==============================] - 105s 665ms/step - loss: 0.0088 - accuracy: 0.9976 - val_loss: 0.1416 - val_accuracy: 0.9338 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 37/200
# 158/158 [==============================] - ETA: 0s - loss: 0.0026 - accuracy: 0.9988
# Epoch 00037: val_accuracy did not improve from 0.96691
# 158/158 [==============================] - 105s 664ms/step - loss: 0.0026 - accuracy: 0.9988 - val_loss: 0.1534 - val_accuracy: 0.9522 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 38/200
# 158/158 [==============================] - ETA: 0s - loss: 5.7204e-04 - accuracy: 1.0000
# Epoch 00038: val_accuracy did not improve from 0.96691
# 158/158 [==============================] - 105s 667ms/step - loss: 5.7204e-04 - accuracy: 1.0000 - val_loss: 0.1628 - val_accuracy: 0.9449 - lr: 3.1623e-05
# Learning rate:  0.0001
# Epoch 39/200
# 158/158 [==============================] - ETA: 0s - loss: 0.0020 - accuracy: 0.9992
# Epoch 00039: val_accuracy did not improve from 0.96691
# 158/158 [==============================] - 105s 667ms/step - loss: 0.0020 - accuracy: 0.9992 - val_loss: 0.1899 - val_accuracy: 0.9522 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 40/200
# 158/158 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 0.9996
# Epoch 00040: val_accuracy did not improve from 0.96691
# 158/158 [==============================] - 105s 666ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.1847 - val_accuracy: 0.9522 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 41/200
# 158/158 [==============================] - ETA: 0s - loss: 8.8248e-04 - accuracy: 1.0000
# Epoch 00041: val_accuracy did not improve from 0.96691
# 158/158 [==============================] - 106s 669ms/step - loss: 8.8248e-04 - accuracy: 1.0000 - val_loss: 0.2411 - val_accuracy: 0.9338 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 42/200
# 158/158 [==============================] - ETA: 0s - loss: 0.0010 - accuracy: 0.9996
# Epoch 00042: val_accuracy did not improve from 0.96691
# 158/158 [==============================] - 106s 669ms/step - loss: 0.0010 - accuracy: 0.9996 - val_loss: 0.1799 - val_accuracy: 0.9449 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 43/200
# 158/158 [==============================] - ETA: 0s - loss: 0.0024 - accuracy: 0.9988
# Epoch 00043: val_accuracy did not improve from 0.96691
# 158/158 [==============================] - 106s 668ms/step - loss: 0.0024 - accuracy: 0.9988 - val_loss: 0.2235 - val_accuracy: 0.9449 - lr: 3.1623e-05
# Learning rate:  0.0001
# Epoch 44/200
# 158/158 [==============================] - ETA: 0s - loss: 0.0020 - accuracy: 0.9992
# Epoch 00044: val_accuracy did not improve from 0.96691
# 158/158 [==============================] - 106s 668ms/step - loss: 0.0020 - accuracy: 0.9992 - val_loss: 0.2337 - val_accuracy: 0.9449 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 45/200
# 158/158 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 0.9996
# Epoch 00045: val_accuracy did not improve from 0.96691
# 158/158 [==============================] - 107s 679ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.
- lr: 1.0000e-07
# Learning rate:  1.0000000000000001e-07
# Epoch 124/200
# 158/158 [==============================] - ETA: 0s - loss: 7.3310e-04 - accuracy: 1.0000
# Epoch 00124: val_accuracy improved from 0.96691 to 0.97794, saving model to /content/drive/My Drive/MyPy/data/saved_models/model-Xception-best.h5
# 158/158 [==============================] - 104s 656ms/step - loss: 7.3310e-04 - accuracy: 1.0000 - val_loss: 0.0905 - val_accuracy: 0.9779 - lr: 1.0000e-07
# Learning rate:  1.0000000000000001e-07
# Epoch 125/200
# 158/158 [==============================] - ETA: 0s - loss: 3.5406e-04 - accuracy: 1.0000
# Epoch 00125: val_accuracy did not improve from 0.97794
# 158/158 [==============================] - 101s 640ms/step - loss: 3.5406e-04 - accuracy: 1.0000 - val_loss: 0.2131 - val_accuracy: 0.9559 - lr: 1.0000e-07
# Learning rate:  1.0000000000000001e-07
# Epoch 126/200
# 158/158 [==============================] - ETA: 0s - loss: 5.8123e-04 - accuracy: 1.0000
# Epoch 00126: val_accuracy did not improve from 0.97794
# 158/158 [==============================] - 101s 639ms/step - loss: 5.8123e-04 - accuracy: 1.0000 - val_loss: 0.1402 - val_accuracy: 0.9522 - lr: 1.0000e-07
# Learning rate:  1.0000000000000001e-07
# Epoch 127/200
# 158/158 [==============================] - ETA: 0s - loss: 5.4906e-04 - accuracy: 0.9996
# Epoch 00127: val_accuracy did not improve from 0.97794
# 158/158 [==============================] - 101s 637ms/step - loss: 5.4906e-04 - accuracy: 0.9996 - val_loss: 0.1751 - val_accuracy: 0.9485 - lr: 1.0000e-07
# Learning rate:  1.0000000000000001e-07
# Epoch 128/200
# 158/158 [==============================] - ETA: 0s - loss: 0.0038 - accuracy: 0.9996
# Epoch 00128: val_accuracy did not improve from 0.97794
# 158/158 [==============================] - 101s 638ms/step - loss: 0.0038 - accuracy: 0.9996 - val_loss: 0.2343 - val_accuracy: 0.9375 - lr: 1.0000e-07
# Learning rate:  1.0000000000000001e-07
# Epoch 129/200
# 158/158 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 0.9996
# Epoch 00129: val_accuracy did not improve from 0.97794
# 158/158 [==============================] - 101s 639ms/step - loss: 0.0017 - accuracy: 0.9996 - val_loss: 0.2419 - val_accuracy: 0.9375 - lr: 1.0000e-07
# Learning rate:  1.0000000000000001e-07
# Epoch 130/200
# 158/158 [==============================] - ETA: 0s - loss: 1.7297e-04 - accuracy: 1.0000
# Epoch 00130: val_accuracy did not improve from 0.97794
# 158/158 [==============================] - 100s 635ms/step - loss: 1.7297e-04 - accuracy: 1.0000 - val_loss: 0.1583 - val_accuracy: 0.9375 - lr: 1.0000e-07
# Learning rate:  1.0000000000000001e-07
# Epoch 131/200
# 158/158 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 0.9996
# Epoch 00131: val_accuracy did not improve from 0.97794
# 158/158 [==============================] - 100s 636ms/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.1759 - val_accuracy: 0.9522 - lr: 1.0000e-07
# Learning rate:  1.0000000000000001e-07
# Epoch 132/200
# 158/158 [==============================] - ETA: 0s - loss: 4.7419e-04 - accuracy: 1.0000
# Epoch 00132: val_accuracy did not improve from 0.97794
# 158/158 [==============================] - 101s 637ms/step - loss: 4.7419e-04 - accuracy: 1.0000 - val_loss: 0.1508 - val_accuracy: 0.9522 - lr: 1.0000e-07
# Learning rate:  1.0000000000000001e-07
# Epoch 133/200
# 158/158 [==============================] - ETA: 0s - loss: 0.0034 - accuracy: 0.9996
# Epoch 00133: val_accuracy did not improve from 0.97794
# 158/158 [==============================] - 101s 637ms/step - loss: 0.0034 - accuracy: 0.9996 - val_loss: 0.1326 - val_accuracy: 0.9559 - lr: 1.0000e-07
# Learning rate:  1.0000000000000001e-07
# Epoch 134/200
# 158/158 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 0.9992
# Epoch 00134: val_accuracy did not improve from 0.97794
# 158/158 [==============================] - 101s 636ms/step - loss: 0.0012 - accuracy: 0.9992 - val_loss: 0.1718 - val_accuracy: 0.9522 - lr: 1.0000e-07
# Learning rate:  1.0000000000000001e-07
# Epoch 135/200
# 158/158 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 0.9988
# Epoch 00135: val_accuracy did not improve from 0.97794
# 158/158 [==============================] - 101s 637ms/step - loss: 0.0021 - accuracy: 0.9988 - val_loss: 0.1922 - val_accuracy: 0.9412 - lr: 1.0000e-07
# Learning rate:  1.0000000000000001e-07
# Epoch 136/200
# 158/158 [==============================] - ETA: 0s - loss: 8.9344e-04 - accuracy: 0.9996
# Epoch 00136: val_accuracy did not improve from 0.97794
# 158/158 [==============================] - 100s 635ms/step - loss: 8.9344e-04 - accuracy: 0.9996 - val_loss: 0.1824 - val_accuracy: 0.9485 - lr: 1.0000e-07
# Learning rate:  1.0000000000000001e-07
# Epoch 137/200
# 158/158 [==============================] - ETA: 0s - loss: 8.3827e-04 - accuracy: 0.9996
# Epoch 00137: val_accuracy did not improve from 0.97794
# 158/158 [==============================] - 101s 637ms/step - loss: 8.3827e-04 - accuracy: 0.9996 - val_loss: 0.2204 - val_accuracy: 0.9449 - lr: 1.0000e-07
# Learning rate:  1.0000000000000001e-07
# Epoch 138/200
# 158/158 [==============================] - ETA: 0s - loss: 9.6248e-04 - accuracy: 0.9996
# Epoch 00138: val_accuracy did not improve from 0.97794
# 158/158 [==============================] - 100s 636ms/step - loss: 9.6248e-04 - accuracy: 0.9996 - val_loss: 0.1854 - val_accuracy: 0.9412 - lr: 1.0000e-07
# Learning rate:  1.0000000000000001e-07
# Epoch 139/200
# 158/158 [==============================] - ETA: 0s - loss: 6.2559e-04 - accuracy: 0.9996
# Epoch 00139: val_accuracy did not improve from 0.97794
# 158/158 [==============================] - 101s 638ms/step - loss: 6.2559e-04 - accuracy: 0.9996 - val_loss: 0.2389 - val_accuracy: 0.9412 - lr: 1.0000e-07
# Learning rate:  1.0000000000000001e-07
# Epoch 140/200
# 158/158 [==============================] - ETA: 0s - loss: 9.9897e-04 - accuracy: 1.0000
# Epoch 00140: val_accuracy did not improve from 0.97794
# 158/158 [==============================] - 101s 637ms/step - loss: 9.9897e-04 - accuracy: 1.0000 - val_loss: 0.2003 - val_accuracy: 0.9522 - lr: 1.0000e-07
# Learning rate:  1.0000000000000001e-07
# Epoch 141/200
# 158/158 [==============================] - ETA: 0s - loss: 4.7633e-04 - accuracy: 1.0000
# Epoch 00141: val_accuracy did not improve from 0.97794
# ...
# Epoch 00155: val_accuracy did not improve from 0.97794
# 158/158 [==============================] - 101s
val_accuracy did not improve from 0.97794
# 158/158 [==============================] - 102s 643ms/step - loss: 4.0307e-04 - accuracy: 1.0000 - val_loss: 0.2598 - val_accuracy: 0.9375 - lr: 5.0000e-08
# Learning rate:  5.0000000000000004e-08
# Epoch 190/200
# 158/158 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 0.9992
# Epoch 00190: val_accuracy did not improve from 0.97794
# 158/158 [==============================] - 102s 643ms/step - loss: 0.0013 - accuracy: 0.9992 - val_loss: 0.1319 - val_accuracy: 0.9559 - lr: 5.0000e-08
# Learning rate:  5.0000000000000004e-08
# Epoch 191/200
# 158/158 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 0.9992
# Epoch 00191: val_accuracy did not improve from 0.97794
# 158/158 [==============================] - 101s 637ms/step - loss: 0.0017 - accuracy: 0.9992 - val_loss: 0.1905 - val_accuracy: 0.9559 - lr: 5.0000e-08
# Learning rate:  5.0000000000000004e-08
# Epoch 192/200
# 158/158 [==============================] - ETA: 0s - loss: 7.8028e-04 - accuracy: 0.9996
# Epoch 00192: val_accuracy did not improve from 0.97794
# 158/158 [==============================] - 101s 639ms/step - loss: 7.8028e-04 - accuracy: 0.9996 - val_loss: 0.1275 - val_accuracy: 0.9485 - lr: 5.0000e-08
# Learning rate:  5.0000000000000004e-08
# Epoch 193/200
# 158/158 [==============================] - ETA: 0s - loss: 0.0037 - accuracy: 0.9984
# Epoch 00193: val_accuracy did not improve from 0.97794
# 158/158 [==============================] - 102s 645ms/step - loss: 0.0037 - accuracy: 0.9984 - val_loss: 0.1843 - val_accuracy: 0.9449 - lr: 5.0000e-08
# Learning rate:  5.0000000000000004e-08
# Epoch 194/200
# 158/158 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 0.9996
# Epoch 00194: val_accuracy did not improve from 0.97794
# 158/158 [==============================] - 101s 639ms/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.1588 - val_accuracy: 0.9485 - lr: 5.0000e-08
# Learning rate:  5.0000000000000004e-08
# Epoch 195/200
# 158/158 [==============================] - ETA: 0s - loss: 0.0034 - accuracy: 0.9992
# Epoch 00195: val_accuracy did not improve from 0.97794
# 158/158 [==============================] - 101s 637ms/step - loss: 0.0034 - accuracy: 0.9992 - val_loss: 0.1964 - val_accuracy: 0.9485 - lr: 5.0000e-08
# Learning rate:  5.0000000000000004e-08
# Epoch 196/200
# 158/158 [==============================] - ETA: 0s - loss: 0.0020 - accuracy: 0.9992
# Epoch 00196: val_accuracy did not improve from 0.97794
# 158/158 [==============================] - 101s 637ms/step - loss: 0.0020 - accuracy: 0.9992 - val_loss: 0.1863 - val_accuracy: 0.9485 - lr: 5.0000e-08
# Learning rate:  5.0000000000000004e-08
# Epoch 197/200
# 158/158 [==============================] - ETA: 0s - loss: 0.0010 - accuracy: 0.9996
# Epoch 00197: val_accuracy did not improve from 0.97794
# 158/158 [==============================] - 101s 638ms/step - loss: 0.0010 - accuracy: 0.9996 - val_loss: 0.2412 - val_accuracy: 0.9449 - lr: 5.0000e-08
# Learning rate:  5.0000000000000004e-08
# Epoch 198/200
# 158/158 [==============================] - ETA: 0s - loss: 3.5430e-04 - accuracy: 1.0000
# Epoch 00198: val_accuracy did not improve from 0.97794
# 158/158 [==============================] - 101s 636ms/step - loss: 3.5430e-04 - accuracy: 1.0000 - val_loss: 0.1473 - val_accuracy: 0.9706 - lr: 5.0000e-08
# Learning rate:  5.0000000000000004e-08
# Epoch 199/200
# 158/158 [==============================] - ETA: 0s - loss: 0.0048 - accuracy: 0.9984
# Epoch 00199: val_accuracy did not improve from 0.97794
# 158/158 [==============================] - 101s 638ms/step - loss: 0.0048 - accuracy: 0.9984 - val_loss: 0.1401 - val_accuracy: 0.9559 - lr: 5.0000e-08
# Learning rate:  5.0000000000000004e-08
# Epoch 200/200
# 158/158 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 0.9992
# Epoch 00200: val_accuracy did not improve from 0.97794
# 158/158 [==============================] - 101s 641ms/step - loss: 0.0014 - accuracy: 0.9992 - val_loss: 0.2082 - val_accuracy: 0.9412 - lr: 5.0000e-08

# %%
# 載入最佳/最終模型
if use_best :
  net_final = load_model(os.path.join(save_dir, WEIGHTS_BEST))
else:
  net_final = load_model(os.path.join(save_dir, WEIGHTS_LAST))

test_batches.reset()
pred = net_final.predict_generator(test_batches, verbose=1)
# Out:
# WARNING:tensorflow:From <ipython-input-13-f8a9c1f2231e>:11: Model.predict_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.predict, which supports generators.
# 2000/2000 [==============================] - 1212s 606ms/step

# %%
predicted_class_indices = np.argmax(pred, axis=1)
labels = (train_batches.class_indices)
label = dict((v,k) for k,v in labels.items())
predictions = [label[i] for i in predicted_class_indices]
# 修改檔名以符合提交格式
filenames = test_batches.filenames
id = [name.replace('.jpg','').replace('all/','') for name in filenames]
# 輸出 csv 檔 id, flower_class
df = pd.DataFrame({"id":id, "flower_class":predicted_class_indices})
df.to_csv(DATASET_PATH + '/submission.csv', index=False)

# %%
net_final.evaluate_generator(valid_batches, verbose=1)
# Out:
# 18/18 [==============================] - 7s 390ms/step
# [0.00455775810405612, 0.8999999761581421]

# %%
net_final.evaluate_generator(valid_batches, verbose=1)
# Out:
# WARNING:tensorflow:From <ipython-input-15-3a2d650a0e8f>:1: Model.evaluate_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.evaluate, which supports generators.
# 18/18 [==============================] - 155s 9s/step - loss: 0.2075 - accuracy: 0.9357
# [0.20748257637023926, 0.9357143044471741]
